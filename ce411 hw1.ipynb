# %%
from anastruct import SystemElements
ss = SystemElements()

# %%
ss.add_element(location = [[0,0],[0,3]])
ss.add_element(location = [[0,3],[0,6]])
ss.add_element(location = [[0,3],[8,3]])
ss.add_element(location = [[0,6],[8,6]])
ss.add_element(location = [[8,0],[8,3]])
ss.add_element(location = [[8,3],[8,6]])
ss.add_element(location = [[16,0],[16,3]])
ss.add_element(location = [[16,3],[16,6]])
ss.add_element(location = [[8,3],[16,3]])
ss.add_element(location = [[8,6],[16,6]])
ss.add_element(location = [[24,0],[24,3]])
ss.add_element(location = [[24,3],[24,6]])
ss.add_element(location = [[16,3],[24,3]])
ss.add_element(location = [[16,6],[24,6]])

ss.show_structure()

# %%
ss.add_support_fixed(node_id=1)
ss.add_support_fixed(node_id=6)
ss.add_support_fixed(node_id=7)
ss.add_support_fixed(node_id=10)

# %%
ss.q_load(q = -75.08, element_id = 4)
ss.q_load(q = -75.08, element_id = 10)
ss.q_load(q = -75.08, element_id = 14)

ss.q_load(q = -103.59, element_id = 3)
ss.q_load(q = -103.59, element_id = 9)
ss.q_load(q = -103.59, element_id = 13)

# %%
ss.show_structure()

# %%
ss.solve()
# Out:
# array([ 0.        ,  0.        ,  0.        ,  0.00264886,  0.13829647,
#        -0.04783325,  0.12227374,  0.19522944, -0.07984825,  0.00596305,
#         0.29051153, -0.00631126,  0.03706205,  0.41377056, -0.00818464,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        , -0.00596305,  0.29051153,  0.00631126, -0.03706205,
#         0.41377056,  0.00818464,  0.        ,  0.        ,  0.        ,
#        -0.00264886,  0.13829647,  0.04783325, -0.12227374,  0.19522944,
#         0.07984825])

# %%
ss.show_bending_moment()
